# %%
import random
import json
import pickle
import numpy as np
import tensorflow as tf

import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words = []
classes = []
documents = []
ignoreLetters = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordList = nltk.word_tokenize(pattern)
        words.extend(wordList)
        documents.append((wordList, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words:
        bag.append(1) if word in wordPatterns else bag.append(0)

    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)

random.shuffle(training)
training = np.array(training)

trainX = training[:, :len(words)]
trainY = training[:, len(words):]


model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(128, input_shape=(len(trainX[0]),), activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(64, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(trainX), np.array(trainY), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# Epoch 1/200
# 4/4 [==============================] - 2s 11ms/step - loss: 1.3832 - accuracy: 0.2222
# Epoch 2/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3653 - accuracy: 0.3889
# Epoch 3/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.3481 - accuracy: 0.3333
# Epoch 4/200
# 4/4 [==============================] - 0s 5ms/step - loss: 1.2654 - accuracy: 0.3889
# Epoch 5/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2763 - accuracy: 0.4444
# Epoch 6/200
# 4/4 [==============================] - 0s 9ms/step - loss: 1.2429 - accuracy: 0.6111
# Epoch 7/200
# 4/4 [==============================] - 0s 11ms/step - loss: 1.1507 - accuracy: 0.7778
# Epoch 8/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1884 - accuracy: 0.5000
# Epoch 9/200
# 4/4 [==============================] - 0s 6ms/step - loss: 1.1814 - accuracy: 0.5000
# Epoch 10/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0833 - accuracy: 0.6667
# Epoch 11/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9829 - accuracy: 0.7222
# Epoch 12/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.1255 - accuracy: 0.5000
# Epoch 13/200
# 4/4 [==============================] - 0s 8ms/step - loss: 1.0536 - accuracy: 0.4444
# Epoch 14/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9945 - accuracy: 0.6111
# Epoch 15/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.9900 - accuracy: 0.6667
# Epoch 16/200
# 4/4 [==============================] - 0s 9ms/step - loss: 0.9159 - accuracy: 0.7778
# Epoch 17/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.9567 - accuracy: 0.6667
# Epoch 18/200
# 4/4 [==============================] - 0s 7ms/step - loss: 1.0050 - accuracy: 0.6111
# Epoch 19/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.8874 - accuracy: 0.6667
# Epoch 20/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8896 - accuracy: 0.5556
# Epoch 21/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.8501 - accuracy: 0.7222
# Epoch 22/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6983 - accuracy: 0.8889
# Epoch 23/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6989 - accuracy: 0.8333
# Epoch 24/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.8316 - accuracy: 0.6667
# Epoch 25/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.7788 - accuracy: 0.8333
# Epoch 26/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6057 - accuracy: 0.7778
# Epoch 27/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5706 - accuracy: 0.8333
# Epoch 28/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5574 - accuracy: 0.8333
# Epoch 29/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5986 - accuracy: 0.8333
# Epoch 30/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5010 - accuracy: 0.8889
# Epoch 31/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4303 - accuracy: 0.9444
# Epoch 32/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5396 - accuracy: 0.8889
# Epoch 33/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5020 - accuracy: 0.7778
# Epoch 34/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.6015 - accuracy: 0.8333
# Epoch 35/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4965 - accuracy: 0.8333
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5672 - accuracy: 0.8333
# Epoch 37/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5385 - accuracy: 0.8333
# Epoch 38/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5383 - accuracy: 0.8333
# Epoch 39/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5329 - accuracy: 0.7778
# Epoch 40/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3681 - accuracy: 0.8889
# Epoch 41/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.4223 - accuracy: 0.8889
# Epoch 42/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3058 - accuracy: 0.8333
# Epoch 43/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3934 - accuracy: 0.9444
# Epoch 44/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.4799 - accuracy: 0.7778
# Epoch 45/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2570 - accuracy: 0.9444
# Epoch 46/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2642 - accuracy: 0.9444
# Epoch 47/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3584 - accuracy: 0.9444
# Epoch 48/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.4861 - accuracy: 0.8333
# Epoch 49/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2888 - accuracy: 0.8889
# Epoch 50/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3032 - accuracy: 0.9444
# Epoch 51/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3002 - accuracy: 0.9444
# Epoch 52/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3950 - accuracy: 0.8889
# Epoch 53/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2251 - accuracy: 0.9444
# Epoch 54/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.3078 - accuracy: 0.8889
# Epoch 55/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3242 - accuracy: 0.8889
# Epoch 56/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3057 - accuracy: 0.8889
# Epoch 57/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3102 - accuracy: 1.0000
# Epoch 58/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2690 - accuracy: 0.9444
# Epoch 59/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2063 - accuracy: 0.9444
# Epoch 60/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2927 - accuracy: 0.8889
# Epoch 61/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1887 - accuracy: 0.8889
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1979 - accuracy: 0.9444
# Epoch 63/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2056 - accuracy: 0.9444
# Epoch 64/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2215 - accuracy: 0.9444
# Epoch 65/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3396 - accuracy: 0.8333
# Epoch 66/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3645 - accuracy: 0.8333
# Epoch 67/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2039 - accuracy: 0.9444
# Epoch 68/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1684 - accuracy: 0.9444
# Epoch 69/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3401 - accuracy: 0.9444
# Epoch 70/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2443 - accuracy: 0.9444
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3530 - accuracy: 0.7778
# Epoch 72/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2301 - accuracy: 0.9444
# Epoch 73/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2964 - accuracy: 0.8333
# Epoch 74/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2929 - accuracy: 0.8889
# Epoch 75/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1569 - accuracy: 0.9444
# Epoch 76/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1776 - accuracy: 0.8889
# Epoch 77/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2318 - accuracy: 0.9444
# Epoch 78/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3019 - accuracy: 0.8333
# Epoch 79/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3908 - accuracy: 0.8889
# Epoch 80/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2213 - accuracy: 0.9444
# Epoch 81/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1583 - accuracy: 0.9444
# Epoch 82/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2471 - accuracy: 0.9444
# Epoch 83/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1357 - accuracy: 0.9444
# Epoch 84/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.3266 - accuracy: 0.9444
# Epoch 85/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1796 - accuracy: 0.9444
# Epoch 86/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2832 - accuracy: 0.9444
# Epoch 87/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3019 - accuracy: 0.9444
# Epoch 88/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2592 - accuracy: 0.9444
# Epoch 89/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2042 - accuracy: 0.9444
# Epoch 90/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2422 - accuracy: 0.9444
# Epoch 91/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1255 - accuracy: 0.9444
# Epoch 92/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1721 - accuracy: 0.9444
# Epoch 93/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1572 - accuracy: 0.9444
# Epoch 94/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3420 - accuracy: 0.9444
# Epoch 95/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2755 - accuracy: 0.9444
# Epoch 96/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1670 - accuracy: 0.9444
# Epoch 97/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1687 - accuracy: 0.9444
# Epoch 98/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2360 - accuracy: 0.9444
# Epoch 99/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1927 - accuracy: 0.8889
# Epoch 100/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1500 - accuracy: 0.9444
# Epoch 101/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1665 - accuracy: 0.8889
# Epoch 102/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2032 - accuracy: 0.9444
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2113 - accuracy: 0.9444
# Epoch 104/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1352 - accuracy: 0.9444
# Epoch 105/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2273 - accuracy: 0.9444
# Epoch 106/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2100 - accuracy: 0.9444
# Epoch 107/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1493 - accuracy: 0.9444
# Epoch 108/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3230 - accuracy: 0.8333
# Epoch 109/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1939 - accuracy: 0.9444
# Epoch 110/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9444
# Epoch 111/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1543 - accuracy: 0.9444
# Epoch 112/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3112 - accuracy: 0.9444
# Epoch 113/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2347 - accuracy: 0.8889
# Epoch 114/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2325 - accuracy: 0.8889
# Epoch 115/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2590 - accuracy: 0.8889
# Epoch 116/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1898 - accuracy: 0.9444
# Epoch 117/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2202 - accuracy: 0.9444
# Epoch 118/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2002 - accuracy: 0.9444
# Epoch 119/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2371 - accuracy: 0.8889
# Epoch 120/200
# 4/4 [==============================] - 0s 8ms/step - loss: 0.2179 - accuracy: 0.9444
# Epoch 121/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1471 - accuracy: 0.9444
# Epoch 122/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1994 - accuracy: 0.9444
# Epoch 123/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1641 - accuracy: 0.8889
# Epoch 124/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1965 - accuracy: 0.9444
# Epoch 125/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1849 - accuracy: 0.8889
# Epoch 126/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1647 - accuracy: 0.9444
# Epoch 127/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1461 - accuracy: 0.9444
# Epoch 128/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1770 - accuracy: 0.9444
# Epoch 129/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1147 - accuracy: 0.9444
# Epoch 130/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2706 - accuracy: 0.9444
# Epoch 131/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1444 - accuracy: 0.9444
# Epoch 132/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2810 - accuracy: 0.9444
# Epoch 133/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2158 - accuracy: 0.9444
# Epoch 134/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1440 - accuracy: 0.9444
# Epoch 135/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2586 - accuracy: 0.8889
# Epoch 136/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1633 - accuracy: 0.9444
# Epoch 137/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1571 - accuracy: 0.9444
# Epoch 138/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1758 - accuracy: 0.9444
# Epoch 139/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2238 - accuracy: 0.8889
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1261 - accuracy: 0.9444
# Epoch 141/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1952 - accuracy: 0.9444
# Epoch 142/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2249 - accuracy: 0.9444
# Epoch 143/200
# 4/4 [==============================] - 0s 13ms/step - loss: 0.1983 - accuracy: 0.9444
# Epoch 144/200
# 4/4 [==============================] - 0s 7ms/step - loss: 0.2358 - accuracy: 0.9444
# Epoch 145/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1676 - accuracy: 0.9444
# Epoch 146/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1717 - accuracy: 0.9444
# Epoch 147/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1489 - accuracy: 0.9444
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1330 - accuracy: 0.9444
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1713 - accuracy: 0.9444
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9444
# Epoch 151/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1591 - accuracy: 0.8889
# Epoch 152/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2340 - accuracy: 0.8889
# Epoch 153/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.3026 - accuracy: 0.8333
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9444
# Epoch 155/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1955 - accuracy: 0.9444
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2676 - accuracy: 0.9444
# Epoch 157/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1776 - accuracy: 0.9444
# Epoch 158/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1213 - accuracy: 0.9444
# Epoch 159/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1373 - accuracy: 0.9444
# Epoch 160/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2101 - accuracy: 0.8889
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1562 - accuracy: 0.9444
# Epoch 162/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1840 - accuracy: 0.9444
# Epoch 163/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1408 - accuracy: 0.9444
# Epoch 164/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1372 - accuracy: 0.9444
# Epoch 165/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2003 - accuracy: 0.9444
# Epoch 166/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1730 - accuracy: 0.9444
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1749 - accuracy: 0.8889
# Epoch 168/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1674 - accuracy: 0.9444
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1670 - accuracy: 0.9444
# Epoch 170/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1949 - accuracy: 0.9444
# Epoch 171/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1701 - accuracy: 0.9444
# Epoch 172/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1510 - accuracy: 0.9444
# Epoch 173/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1609 - accuracy: 0.9444
# Epoch 174/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1495 - accuracy: 0.9444
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1619 - accuracy: 0.9444
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1960 - accuracy: 0.9444
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1592 - accuracy: 0.9444
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1556 - accuracy: 0.9444
# Epoch 179/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3271 - accuracy: 0.8889
# Epoch 180/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1980 - accuracy: 0.9444
# Epoch 181/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2999 - accuracy: 0.8889
# Epoch 182/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2143 - accuracy: 0.8889
# Epoch 183/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1449 - accuracy: 0.9444
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1737 - accuracy: 0.9444
# Epoch 185/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.9444
# Epoch 186/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1373 - accuracy: 0.9444
# Epoch 187/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1823 - accuracy: 0.9444
# Epoch 188/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1501 - accuracy: 0.9444
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1248 - accuracy: 0.9444
# Epoch 190/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9444
# Epoch 191/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1439 - accuracy: 0.9444
# Epoch 192/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1026 - accuracy: 0.9444
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2065 - accuracy: 0.9444
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1231 - accuracy: 0.9444
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2195 - accuracy: 0.8889
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1995 - accuracy: 0.8889
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1767 - accuracy: 0.9444
# Epoch 198/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1625 - accuracy: 0.9444
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1675 - accuracy: 0.9444
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1559 - accuracy: 0.9444
# Done
# C:\Users\LENOVO\anaconda3\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import random
import json
import pickle
import numpy as np
import nltk

from nltk.stem import WordNetLemmatizer
from keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words (sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class (sentence):
    bow = bag_of_words (sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes [r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice (i['responses'])
            break
    return result

print("GO! Bot is running!")

while True:
    message = input("")
    ints = predict_class (message)
    res = get_response (ints, intents)
    print (res)
# Out:
# GO! Bot is running!
# hi
# 1/1 [==============================] - 0s 198ms/step
# Hello
# Nice chatting to you
# 1/1 [==============================] - 0s 28ms/step
# Bye! Come back again soon.
# Nice chatting to you
# 1/1 [==============================] - 0s 29ms/step
# See you!
# See you later
# 1/1 [==============================] - 0s 34ms/step
# See you!
